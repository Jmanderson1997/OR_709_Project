# %%
import ptvsd 
from reimporter import *
ptvsd.enable_attach()
freeze_modules()

# %%
reimport()
from dp_model import DPModel

model = DPModel()
going = True
i = 0
while going or i<100: 
    going = model.find_path(5)
    i+=1
# Out:
# Still going
# Still going
# Still going
# Still going
# Still going
# Still going
# Still going
# Path Failed. Total balance, steps:36, time:0.72
# session finished please restart
# session finished please restart
# session finished please restart
# session finished please restart
# session finished please restart
# session finished please restart
# session finished please restart
# session finished please restart
# session finished please restart
# session finished please restart
# session finished please restart
# session finished please restart
# session finished please restart
# session finished please restart
# session finished please restart
# session finished please restart
# session finished please restart
# session finished please restart
# session finished please restart
# session finished please restart
# session finished please restart
# session finished please restart
# session finished please restart
# session finished please restart
# session finished please restart
# ...
